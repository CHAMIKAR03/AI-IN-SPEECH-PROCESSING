# %%
#A1

import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

y, sr = librosa.load('recording.mp3')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y)
plt.title('Speech Signal Waveform')
plt.show()

# %%
#A2

print("Length of the signal:",len(y),"samples")
print("Sampling rate:",sr, "Hz")
print("Magnitude range:",np.min(y),"to", np.max(y))
# Out:
# Length of the signal: 81497 samples
# Sampling rate: 22050 Hz
# Magnitude range: -0.12271068 to 0.16023459

# %%
#A3

import IPython.display as ipd

start = int(3 * sr)
end = int(7 * sr).segment = y[start:end]
librosa.display.waveshow(segment)
ipd.Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#A4

segment_1_start = int(1 * sr)
segment_1_end = int(4 * sr)
segment_2_start = int(5 * sr)
segment_2_end = int(9 * sr)
segment_1 = y[segment_1_start:segment_1_end]
segment_2 = y[segment_2_start:segment_2_end]
print("Playing Segment 1:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_1)
plt.title('Segment-1')
plt.show()
ipd.Audio(segment_1, rate=sr)
# Out:
# Playing Segment 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Segment 2:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_2)
plt.title('Segment-1')
plt.show()
ipd.Audio(segment_2, rate=sr)
# Out:
# Playing Segment 2:
# ---------------------------------------------------------------------------
# ParameterError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26828\3189520458.py in <module>
#       2
#       3 plt.figure(figsize=(10, 5))
# ----> 4 librosa.display.waveshow(segment_2)
#       5 plt.title('Segment-1')
#       6 plt.show()
#
# ~\.android\lib\site-packages\librosa\display.py in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2045     # this choice of hop ensures that the envelope has at most max_points values
#    2046     hop_length = max(1, y.shape[-1] // max_points)
# -> 2047     y_env = __envelope(y, hop_length)
#    2048
#    2049     # Split the envelope into top and bottom
#
# ~\.android\lib\site-packages\librosa\display.py in __envelope(x, hop)
#     867     x is assumed to be multi-channel, of shape (n_channels, n_samples).
#     868     """
# --> 869     x_frame = np.abs(util.frame(x, frame_length=hop, hop_length=hop))
#     870     return x_frame.max(axis=1)
#     871
#
# ~\.android\lib\site-packages\librosa\util\utils.py in frame(x, frame_length, hop_length, axis, writeable, subok)
#     204
#     205     if x.shape[axis] < frame_length:
# --> 206         raise ParameterError(
#     207             f"Input is too short (n={x.shape[axis]:d}) for frame_length={frame_length:d}"
#     208         )
#
# ParameterError: Input is too short (n=0) for frame_length=1
